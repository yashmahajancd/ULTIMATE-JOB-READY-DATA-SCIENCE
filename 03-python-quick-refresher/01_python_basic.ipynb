# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
name = "Yash"

# %%
name
# Out:
# 'Yash'

# %%
print("Hello World") # this will print Hello World on the screen
# Out:
# Hello World

# %%
# this is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(a)
# Out:
# int

# %%
print(type(name))
type(name)
# Out:
# <class 'str'>
# str

# %%
a = "38745"
b = "83649"

# %%
print(a + b)
# Out:
# 3874583649

# %%
int(a) + int(b) # Typecasting
# Out:
# 122394
