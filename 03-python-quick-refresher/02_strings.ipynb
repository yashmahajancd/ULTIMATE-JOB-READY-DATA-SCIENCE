# %%
name = "Yash Mahajan"

# %%
name
# Out:
# 'Yash Mahajan'

# %%
name.upper()
# Out:
# 'YASH MAHAJAN'

# %%
name.endswith("an")
# Out:
# True

# %%
name.endswith("sh")
# Out:
# False

# %%
name.lower()
# Out:
# 'yash mahajan'

# %%
name.count("a")
# Out:
# 4

# %%
name.count("j")
# Out:
# 1

# %%
print(len(name)) # returns length of string
# Out:
# 12

# %%
name2 = "    Yash    "
print(name2.strip()) # removes spaces
# Out:
# Yash

# %%
s1 = "Hello World"
print(s1.replace("World", "Python")) # replaces a substring with another
# Out:
# Hello Python

# %%
s2 = "apple,banana,grape"
print(s2.split(",")) # splits a string into a list based on a delimiter
# Out:
# ['apple', 'banana', 'grape']

# %%
s3 = ["Hello", "Python"]
print(" ".join(s3)) # joins elements of a list into a string using a separator
# Out:
# Hello Python

# %%
s4 = "Hello Python"
print(s4.find("Python")) # returns the index of the first occurrence of a substring
# Out:
# 6

# %%
s5 = "hello.py"

# checks if a string starts or ends with a specific substring
print(s5.startswith("hello"))
print(s5.endswith(".py"))
# Out:
# True
# True

# %%
username = "yashmahajancd"
username[0:11]
# Out:
# 'yashmahajan'

# %%
username[1:-1]
# Out:
# 'ashmahajanc'

# %%
username[1:12]
# Out:
# 'ashmahajanc'

# %%
username[-12:-1]
# Out:
# 'ashmahajanc'

# %%
username[0:]
# Out:
# 'yashmahajancd'
