# %% [markdown]
# ### 1. Arithmetic Operators

# %%
a = 11
b = 5

# %%
a + b
# Out:
# 16

# %%
a - b
# Out:
# 6

# %%
a * b
# Out:
# 55

# %%
a / b
# Out:
# 2.2

# %%
a // b
# Out:
# 2

# %%
2 ** 2
# Out:
# 4

# %%
2 ** 5
# Out:
# 32

# %%
a ** b
# Out:
# 161051

# %%
a % b
# Out:
# 1

# %% [markdown]
# ### 2. Comparison Operators

# %%
x = 45
y = 4

# %%
x < y
# Out:
# False

# %%
x > y
# Out:
# True

# %%
x >= y
# Out:
# True

# %%
a == x # is a equal to x?
# Out:
# False

# %%
a != x
# Out:
# True

# %%
n = 5
m = 5

# %%
n == m
# Out:
# True

# %%
n >= m
# Out:
# True

# %%
n <= m
# Out:
# True

# %% [markdown]
# ### 3. Logical Operators

# %%
b1 = True
b2 = False

# %%
not(b1) # negation
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %% [markdown]
# ### 4. Bitwise Operators

# %%
i = 5
j = 3

# %%
i & j
# Out:
# 1

# %%
i | j
# Out:
# 7

# %% [markdown]
# ### 5. Assignment Operators

# %%
o = 45

# %%
o += 4

# %%
o
# Out:
# 49

# %%
o -= 6

# %%
o
# Out:
# 43

# %%
p = 10

# %%
p *= 5

# %%
p
# Out:
# 50

# %%
p /= 2

# %%
p
# Out:
# 25.0

# %%
q = 25

# %%
q //= 2

# %%
q
# Out:
# 12

# %%
q %= 5

# %%
q
# Out:
# 2

# %%
q **= 3

# %%
q
# Out:
# 8

# %% [markdown]
# ### 6. Membership & Identity Operators

# %%
list1 = [1, 2, 3]
x = 2

# %%
x in list1   # present in sequence
# Out:
# True

# %%
x not in list1   # not present
# Out:
# False

# %%
s = 10
t = 5
u = s
v = 5

# %%
s is t
# Out:
# False

# %%
s is not t
# Out:
# True

# %%
s is u
# Out:
# True

# %%
t is v
# Out:
# True
