# %%
import json

# write a function to load the data
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
    return data

# write a function to display users and their connections
def display_users(data):
    print("Users and their connections:")
    print("-------------------------------------------------------")
    for user in data['users']:
        print(f"ID:{user['id']} - {user['name']} are friends with {user['friends']} and liked pages are {user['liked_pages']}")

    print("\nPage Information:")
    print("----------------------------------")
    for page in data['pages']:
        print(f"{page['id']} - {page['name']}")

# load the data
data = load_data("massive_data.json")
display_users(data)
# Out:
# Users and their connections:
# -------------------------------------------------------
# ID:1 - Amit are friends with [2, 3, 4, 5, 6] and liked pages are [101, 102]
# ID:2 - Priya are friends with [1, 3, 5, 6, 7] and liked pages are [102, 103]
# ID:3 - Rahul are friends with [1, 2, 4, 7, 8] and liked pages are [101, 103]
# ID:4 - Sara are friends with [1, 3, 6, 8, 9] and liked pages are [104]
# ID:5 - Neha are friends with [1, 2, 6, 10, 11] and liked pages are [102, 105]
# ID:6 - Vikram are friends with [1, 2, 4, 5, 12] and liked pages are [106]
# ID:7 - Kunal are friends with [2, 3, 8, 9, 13] and liked pages are [101, 107]
# ID:8 - Anjali are friends with [3, 4, 7, 10, 14] and liked pages are [103, 108]
# ID:9 - Ravi are friends with [4, 7, 10, 11, 15] and liked pages are [104, 109]
# ID:10 - Sneha are friends with [5, 8, 9, 12, 16] and liked pages are [110]
# ID:11 - Arjun are friends with [5, 9, 12, 14, 17] and liked pages are [105, 111]
# ID:12 - Meera are friends with [6, 10, 11, 13, 18] and liked pages are [112]
# ID:13 - Kabir are friends with [7, 12, 14, 15, 19] and liked pages are [106, 113]
# ID:14 - Tanya are friends with [8, 11, 13, 16, 20] and liked pages are [114]
# ID:15 - Varun are friends with [9, 13, 16, 17, 21] and liked pages are [107, 115]
# ID:16 - Rhea are friends with [10, 14, 15, 18, 22] and liked pages are [116]
# ID:17 - Ishan are friends with [11, 15, 18, 19, 23] and liked pages are [108, 117]
# ID:18 - Simran are friends with [12, 16, 17, 20, 24] and liked pages are [118]
# ID:19 - Pooja are friends with [13, 17, 20, 21, 25] and liked pages are [109, 119]
# ID:20 - Yash are friends with [14, 18, 19, 22, 26] and liked pages are [120]
# ID:21 - Ananya are friends with [15, 19, 22, 23, 27] and liked pages are [110, 121]
# ID:22 - Dev are friends with [16, 20, 21, 24, 28] and liked pages are [122]
# ID:23 - Aditi are friends with [17, 21, 24, 25, 29] and liked pages are [111, 123]
# ID:24 - Rohan are friends with [18, 22, 23, 26, 30] and liked pages are [124]
# ID:25 - Nisha are friends with [19, 23, 26, 27, 1] and liked pages are [112]
# ID:26 - Gautam are friends with [20, 24, 25, 28, 3] and liked pages are [125]
# ID:27 - Kriti are friends with [21, 25, 28, 29, 5] and liked pages are [113]
# ID:28 - Harsh are friends with [22, 26, 27, 30, 7] and liked pages are [126]
# ID:29 - Naveen are friends with [23, 27, 30, 9, 11] and liked pages are [114]
# ID:30 - Ishita are friends with [24, 28, 29, 13, 15] and liked pages are [127]
#
# Page Information:
# ----------------------------------
# 101 - Python Developers
# 102 - Data Science Enthusiasts
# 103 - AI & ML Community
# 104 - Web Dev Hub
# 105 - Blockchain Innovators
# 106 - Cybersecurity Experts
# 107 - Cloud Computing Pros
# 108 - Competitive Programmers
# 109 - Startup Founders
# 110 - UI/UX Designers
# 111 - Full-Stack Developers
# 112 - Tech Entrepreneurs
# 113 - IoT Enthusiasts
# 114 - Game Developers
# 115 - Big Data Analysts
# 116 - DevOps Engineers
# 117 - Cloud AI Researchers
# 118 - 5G & Edge Computing
# 119 - AR/VR Creators
# 120 - Freelance Coders
# 121 - Open Source Contributors
# 122 - Algorithmic Traders
# 123 - Low-Code Developers
# 124 - Cyber Ethics Forum
# 125 - AI Ethics & Policy
# 126 - Digital Nomads
# 127 - Women in Tech
