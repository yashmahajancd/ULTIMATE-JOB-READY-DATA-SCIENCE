# %%
import numpy as np

# %%
arr = np.array([23, 4, 3, 23])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype('float64')
# Out:
# array([23.,  4.,  3., 23.])

# %%
arr
# Out:
# array([23,  4,  3, 23])

# %%
arr2 = np.array([23,  4,  3, 23], dtype='float64')

# %%
arr2
# Out:
# array([23.,  4.,  3., 23.])

# %% [markdown]
# #### Example: Memory Usage

# %%
arr_int64 = np.array([1, 2, 3], dtype='int64')
arr_int32 = np.array([1, 2, 3], dtype='int32')

print(arr_int64.nbytes)
print(arr_int32.nbytes)
print(arr.nbytes)
print(arr2.nbytes)
# Out:
# 24
# 12
# 32
# 32

# %% [markdown]
# ### String Data Type in NumPy

# %%
arr = np.array(['apple', 'banana', 'cherry'], dtype='U10')

# %%
print(arr)
# Out:
# ['apple' 'banana' 'cherry']

# %% [markdown]
# ### Complex Numbers

# %%
arr = np.array([1 + 2j, 3 + 4j, 5 + 6j], dtype='complex128')

# %%
print(arr)
# Out:
# [1.+2.j 3.+4.j 5.+6.j]

# %% [markdown]
# ### Object Data Type

# %%
arr = np.array([{'a': 1}, [1, 2, 3], 'hello'], dtype=object)

# %%
print(arr)
# Out:
# [{'a': 1} list([1, 2, 3]) 'hello']

# %% [markdown]
# ### Note - Choosing the Right Data Type
# - Choosing the correct data type is essential for:
# - Optimizing memory: Using the smallest data type that fits your data.
# - Improving performance: Smaller types generally lead to faster operations.
# - Ensuring precision: Avoid truncating or losing important decimal places or values.
