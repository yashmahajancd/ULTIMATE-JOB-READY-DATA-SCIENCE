# %% [markdown]
# # 🧠 Questions
#
# ---
#
# # 1️⃣ Die Probability
#
# You roll a fair six-sided die.
#
# What is the probability of getting an even number?
#
# ---
#
# # 2️⃣ Coin Toss Sample Space
#
# Two coins are tossed.
#
# Find the sample space associated with this random experiment.
#
# ---
#
# # 3️⃣ Sum of Two Dice
#
# Two six-sided dice are rolled.
#
# What is the probability that the sum is `7`?
#
# ---
#
# # 4️⃣ Probability from a Bag
#
# A bag contains:
#
# - 3 Red balls
# - 2 Blue balls
# - 5 Green balls
#
# What is the probability of randomly selecting a red ball?
#
# ---
#
# # 5️⃣ Probability with Cards
#
# A card is drawn randomly from a deck.
#
# Find the probability of:
#
# - Getting a heart
# - Getting a face card
