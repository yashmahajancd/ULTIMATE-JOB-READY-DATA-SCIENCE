# %% [markdown]
# # 📘 Basic Rules of Probability
#
# ---
#
# # 📌 1. Important Definitions
#
# In probability, understanding the basic definitions is crucial for learning advanced concepts.
#
# ---
#
# # 🔹 Experiment
#
# An action or process that leads to one or more outcomes.
#
# Examples:
#
# - Rolling a die
# - Tossing a coin
#
# ---
#
# ## 📌 Types of Experiments
#
# ### ✅ Deterministic Experiment
#
# Produces predictable outcomes.
#
# ### ✅ Probabilistic / Random Experiment
#
# Produces uncertain outcomes.
#
# ---
#
# # 🔹 Outcome
#
# A possible result of an experiment.
#
# ### 💡 Example
#
# Rolling a `3` on a die.
#
# ---
#
# # 🔹 Probability `P`
#
# Probability measures how likely an event is to occur.
#
# It ranges from:
#
# - `0` → Impossible event
# - `1` → Certain event
#
# ---
#
# # 🔹 `P(A ∪ B)`
#
# Probability that:
#
# - Event `A`
# - OR Event `B`
#
# occurs.
#
# ---
#
# # 🔹 `P(A ∩ B)`
#
# Probability that:
#
# - Both `A`
# - AND `B`
#
# occur together.
#
# ---
#
# # 🔹 Sample Space `(S)`
#
# The set of all possible outcomes of an experiment.
#
# ---
#
# # 🔹 Event `(E)`
#
# A subset of the sample space.
#
# ---
#
# # 🔹 Mutually Exclusive Events
#
# Two events that cannot occur at the same time.
#
# ---
#
# ## 💡 Example
#
# - Event `A` → Rolling a `2`
# - Event `B` → Rolling a `5`
#
# A die cannot show both together.
#
# `P(A∩B)=0`
#
# ---
#
# # 🔹 Independent Events
#
# Two events where the occurrence of one does not affect the other.
#
# `P(A∩B)=P(A)⋅P(B)`
#
# ---
#
# # 🔹 Certain Event
#
# An event that is guaranteed to happen, with a probability of 1.
#
# ---
#
# # 🔹 Impossible Event
#
# An event that cannot happen, with a probability of 0.
#
# ---
#
# # 🔹 Exhaustive Events
#
# A set of events that cover the entire sample space,
# meaning at least one of them must occur.
#
# ---
#
# # 💼 Example: Tossing a Die
#
# ### 🎲 Sample Space
#
# ```text
# S = {1, 2, 3, 4, 5, 6}
# ```
#
# ---
#
# ### 🎯 Event (Even Numbers)
#
# ```text
# E = {2, 4, 6}
# ```
#
# ---
#
# # 📌 2. The Complement Rule
#
# The complement of an event `A` means:
#
# > Event `A` does NOT occur.
#
# Notation:
#
# ```text
# Aᶜ
# ```
#
# ---
#
# # 📐 Formula
#
# `P(Aᶜ) = 1 − P(A)`
#
# ---
#
# # 💡 Example
#
# If the probability of rain today is 0.3, the probability it won’t rain is:
#
# `P(No Rain) = 1
# − 0.3 = 0.7`
#
# ---
#
# # 📌 3. The Addition Rule
#
# Used to calculate the probability of the union of two events.
#
# ---
#
# # 🔹 For General Events
#
#
# `P(A or B) = P(A) + P(B) − P(A and B)`
#
#
# ---
#
# # 🔹 For Mutually Exclusive Events
#
# `P(A or B) = P(A) + P(B)`
#
# ---
#
# # 💡 Example
#
# Given:
#
# - `P(A) = 0.4, P(B) = 0.5, P(A ∩ B) = 0.2`
# - `P(A or B) = 0.4 + 0.5 − 0.2 = 0.7`
#
# ---
#
# # 📌 4. The Multiplication Rule
#
# Used to find the probability that two events occur together.
#
# ---
#
# # 🔹 For Independent Events
#
#
# P(A and B) = P(A) × P(B)
#
#
# ---
#
# # 💼 Example
#
# - Event `A` → Rolling a `3`
# - Event `B` → Rolling an even number
#
# Given:
#
# `P(A) = 1/6 (rolling a 3)`
#
# `P(B) = 3/6 (rolling a 2, 4, or 6)`
#
# Then:
#
#
# `P(A and B) = P(A) × P(B) = (1/6) × (3/6) = 1/12`
#
#
# ---
#
# # 🔹 For Dependent Events
#
#
# `P(A and B) = P(A) × P(B | A)`
#
#
# ---
#
# # 💼 Example: Balls Without Replacement
#
# A bag contains:
#
# - 5 Red balls
# - 3 Blue balls
#
# Two balls are drawn without replacement.
#
# ---
#
# ## 🎯 Define Events
#
# - Event `A` → First ball is red
# - Event `B` → Second ball is red
#
# ---
#
# ## 📌 Probabilities
#
# `P(A) = 5/8 (5 red balls out of 8)`
#
# After removing one red ball, there are 4 red left out of 7 total:
#
# `P(B/A) = 4/7`
#
# Then:
#
#
# `P(A and B) = (5/8) X (4/7)= 20/56 = 5/14`
#
# So the probability of drawing two red balls **without replacement** is 5/14
#
# ---
#
# # 📌 5. Independent vs Dependent Events
#
# ---
#
# # 🔹 Independent Events
#
# The outcome of one event does not affect the other.
#
# ### 💡 Example
#
# Tossing two coins.
#
# ---
#
# # 🔹 Dependent Events
#
# One event affects the probability of the other.
#
# ### 💡 Example
#
# Drawing two cards without replacement.
#
# ---
#
# # 📌 6. Mutually Exclusive Events
#
# Two events are mutually exclusive if they cannot happen at the same time.
#
# ---
#
# # 💡 Example
#
# - Event `A` → Rolling a `2`
# - Event `B` → Rolling a `5`
# - These are mutually exclusive because a die can’t show both at once.
#
# ---
#
# # 📋 Summary
#
# This lesson covered key probability rules and concepts that are foundational for
# more advanced topics like distributions and statistical inference.
#
# ---
#
# # ✅ Important Rules
#
# - Complement Rule:
#
# `P(Aᶜ) = 1 − P(A)`
#
# - Addition Rule for unions
#
# - Multiplication Rule for intersections
#
# - Understanding independence and exclusivity
#
#
# ---
#
# # 📝 Homework / Practice
#
# ## 1️⃣ Cards Probability
#
# A card is drawn from a standard deck.
#
# Find the probability of drawing:
#
# - A red card
# - A queen
#
# ---
#
# ## 2️⃣ Dice Probability
#
# If two dice are rolled,
# what is the probability that both show even numbers?
#
# ---
#
# ## 3️⃣ Daily Life Example
#
# Think of an example from daily life where two events are dependent.
#
# ---
#
# # ✅ Conclusion
#
# Understanding probability rules is essential for:
#
# - Statistical analysis
# - Machine learning
# - Risk prediction
# - Data-driven decision making
#
# These concepts form the mathematical foundation of probability and statistics.
#
# ---
