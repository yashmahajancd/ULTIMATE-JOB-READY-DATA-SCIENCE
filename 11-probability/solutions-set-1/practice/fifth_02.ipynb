# %%
TOTAL_CARDS = 52
SUITS = 4

# %%
hearts_in_deck = 13
prob_heart = hearts_in_deck / TOTAL_CARDS

# %%
prob_heart
# Out:
# 0.25

# %%
face_card_per_suit = 3
total_face_cards = face_card_per_suit * SUITS
prob_face_card = total_face_cards / TOTAL_CARDS

# %%
total_face_cards
# Out:
# 12

# %%
prob_face_card
# Out:
# 0.23076923076923078

# %% [markdown]
# ---

# %%
print(f"Getting a heart : {hearts_in_deck}/{TOTAL_CARDS} = {prob_heart:.2f}")
print(f"Getting a face card : {total_face_cards}/{TOTAL_CARDS} = {prob_face_card:.4f}")
# Out:
# Getting a heart : 0.25
# Getting a face card : 0.2308
