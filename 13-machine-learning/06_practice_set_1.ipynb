# %% [markdown]
# # 🧠 Questions
#
# ---
#
# # 1️⃣ Fruit Classification Using Decision Tree
#
# Build a **Decision Tree** model to classify whether a fruit is an **Apple** or an **Orange** based on the following features:
#
# - Weight (grams)
# - Color (0 = Red, 1 = Orange)
#
# Predict the class for:
#
# - Weight = **160**, Color = **0**
# - Weight = **115**, Color = **1**
#
# ---
#
# # 2️⃣ Student Pass/Fail Prediction
#
# Build a **Decision Tree** model to predict whether a student will **Pass** or **Fail**.
#
# Features:
#
# - Study Hours
# - Attendance (%)
#
# Target:
#
# - Pass
# - Fail
#
# Predict the outcome for:
#
# - Study Hours = **7**
# - Attendance = **90%**
#
# ---
#
# # 3️⃣ Cricket Playing Prediction
#
# Build a **Decision Tree** model to predict whether a person will **Play Cricket**.
#
# Features:
#
# - Temperature
# - Humidity
#
# Target:
#
# - Play
# - Don't Play
#
# Predict the outcome for:
#
# - Temperature = **27°C**
# - Humidity = **65%**
#
# ---
#
# # 4️⃣ Loan Approval Prediction
#
# Build a **Decision Tree** model to predict whether a loan application should be **Approved** or **Rejected**.
#
# Features:
#
# - Monthly Salary (₹)
# - Credit Score
#
# Target:
#
# - Approved
# - Rejected
#
# Predict the outcome for:
#
# - Monthly Salary = **₹70,000**
# - Credit Score = **720**
#
# ---
#
# # 5️⃣ Animal Classification Using Decision Tree
#
# Build a **Decision Tree** model to classify whether an animal is a **Cat** or a **Dog**.
#
# Features:
#
# - Weight (kg)
# - Tail Length (cm)
#
# Target:
#
# - Cat
# - Dog
#
# Predict the class for:
#
# - Weight = **18 kg**
# - Tail Length = **55 cm**
#
# ---
