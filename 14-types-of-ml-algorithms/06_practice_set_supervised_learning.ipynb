# %% [markdown]
# # 🧠 Supervised Learning Questions
#
# ---
#
# # 1️⃣ Fruit Classification Using Decision Tree
#
# Build a **Decision Tree** model to classify whether a fruit is an **Apple** or an **Orange**.
#
# Features:
#
# - Weight (grams)
# - Color (0 = Red, 1 = Orange)
#
# ---
#
# # 2️⃣ Student Pass or Fail Prediction
#
# Build a **Decision Tree** model to predict whether a student will **Pass** or **Fail**.
#
# Features:
#
# - Study Hours
# - Attendance
#
# Target:
#
# - Pass
# - Fail
#
# ---
#
# # 3️⃣ Salary Prediction Using Linear Regression
#
# Build a **Linear Regression** model to predict an employee's **Salary**.
#
# Feature:
#
# - Experience (Years)
#
# Target:
#
# - Salary
#
# ---
#
# # 4️⃣ House Price Prediction Using Linear Regression
#
# Build a **Linear Regression** model to predict the **Price** of a house.
#
# Feature:
#
# - Area (sq ft)
#
# Target:
#
# - Price
#
# ---
#
# # 5️⃣ Email Spam Detection
#
# Build a **classification model** to predict whether an email is **Spam** or **Not Spam**.
#
# Feature:
#
# - Number of Suspicious Words
#
# Target:
#
# - Spam
# - Not Spam
#
# ---
