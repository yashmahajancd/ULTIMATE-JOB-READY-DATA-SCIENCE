# %% [markdown]
# # 🧠 Unsupervised Learning Questions
#
# ---
#
# # 1️⃣ Fruit Grouping Using K-Means Clustering
#
# Build a **K-Means Clustering** model to group fruits into **2 clusters** based on their similarities.
#
# Features:
#
# - Weight (grams)
# - Color (0 = Red, 1 = Orange)
#
# ---
#
# # 2️⃣ Student Performance Grouping
#
# Build a **K-Means Clustering** model to group students into **2 clusters** based on their performance.
#
# Features:
#
# - Study Hours
# - Attendance
#
# ---
#
# # 3️⃣ Customer Segmentation Using K-Means Clustering
#
# Build a **K-Means Clustering** model to group customers into **3 clusters**.
#
# Features:
#
# - Age
# - Annual Income (₹)
#
# ---
#
# # 4️⃣ Flower Clustering
#
# Build a **K-Means Clustering** model to group flowers into **2 clusters** based on their characteristics.
#
# Features:
#
# - Petal Length
# - Petal Width
#
# ---
#
# # 5️⃣ House Grouping Using K-Means Clustering
#
# Build a **K-Means Clustering** model to group houses into **2 clusters** based on their similarities.
#
# Features:
#
# - Area (sq ft)
# - Price
#
# ---
