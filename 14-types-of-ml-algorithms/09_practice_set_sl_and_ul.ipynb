# %% [markdown]
# # 🧠 Questions - Combination of Supervised + Unsupervised Learning
#
# ---
#
# # 1️⃣ Student Performance Analysis and Prediction
#
# A school wants to:
#
# 1. Group students based on **Study Hours** and **Attendance**.
# 2. Predict whether a student will **Pass** or **Fail**.
#
# ### Step 1: Cluster Students
#
# ```python
# students = [
#     [5, 80],
#     [6, 90],
#     [1, 40],
#     [2, 50],
#     [7, 95]
# ]
# ```
#
# ### Step 2: Use Labels for Prediction
#
# ```python
# labels = [
#     "Pass",
#     "Pass",
#     "Fail",
#     "Fail",
#     "Pass"
# ]
# ```
#
# Predict the outcome for:
#
# ```python
# [4, 85]
# ```
#
# ---
#
# # 2️⃣ Customer Segmentation and Purchase Prediction
#
# An online store wants to:
#
# 1. Segment customers into groups.
# 2. Predict whether a customer will purchase a product.
#
# Features:
#
# - Age
# - Annual Income
#
# ### Data
#
# ```python
# customers = [
#     [20, 30000],
#     [22, 35000],
#     [25, 40000],
#     [45, 80000],
#     [50, 90000]
# ]
# ```
#
# ```python
# purchase = [
#     0,
#     0,
#     1,
#     1,
#     1
# ]
# ```
#
# Predict the outcome for:
#
# ```python
# [30, 50000]
# ```
#
# ---
#
# # 3️⃣ House Clustering and Price Prediction
#
# A real estate company wants to:
#
# 1. Group houses into categories.
# 2. Predict house prices.
#
# Features:
#
# - Area (sq ft)
#
# Target:
#
# - Price
#
# ### Data
#
# ```python
# area = [
#     [1000],
#     [1200],
#     [1500],
#     [1800],
#     [2000]
# ]
# ```
#
# ```python
# price = [
#     3000000,
#     3600000,
#     4500000,
#     5400000,
#     6000000
# ]
# ```
#
# Predict the price for:
#
# ```python
# 1700
# ```
#
# sq ft
#
# ---
#
# # 4️⃣ Flower Grouping and Species Prediction
#
# A botanist wants to:
#
# 1. Discover flower groups.
# 2. Predict flower species.
#
# Features:
#
# - Petal Length
# - Petal Width
#
# ### Data
#
# ```python
# flowers = [
#     [1.4, 0.2],
#     [1.5, 0.3],
#     [5.0, 1.8],
#     [5.2, 2.0]
# ]
# ```
#
# ```python
# species = [
#     "Setosa",
#     "Setosa",
#     "Versicolor",
#     "Versicolor"
# ]
# ```
#
# Predict the species for:
#
# ```python
# [1.6, 0.2]
# ```
#
# ---
#
# # 5️⃣ Employee Segmentation and Salary Prediction
#
# A company wants to:
#
# 1. Group employees based on **Experience**.
# 2. Predict **Salary**.
#
# ### Data
#
# ```python
# experience = [
#     [1],
#     [2],
#     [3],
#     [4],
#     [5]
# ]
# ```
#
# ```python
# salary = [
#     25000,
#     35000,
#     45000,
#     55000,
#     65000
# ]
# ```
#
# Predict the salary for:
#
# ```python
# 6
# ```
#
# years of experience.
#
# ---
