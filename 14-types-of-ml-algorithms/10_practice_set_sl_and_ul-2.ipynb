# %% [markdown]
# # 🧠 Questions - Combination of Supervised + Unsupervised Learning
#
# ---
#
# # 1️⃣ Loan Customer Analysis
#
# Build a machine learning solution for **Loan Customer Analysis**.
#
# Features:
#
# - Income
# - Credit Score
#
# Tasks:
#
# 1. Group customers into **3 clusters**.
# 2. Predict whether a loan application will be **Approved** or **Rejected**.
#
# ---
#
# # 2️⃣ Gym Member Analysis
#
# Build a machine learning solution for **Gym Member Analysis**.
#
# Features:
#
# - Age
# - Weight
#
# Tasks:
#
# 1. Create **2 clusters** of gym members.
# 2. Predict the **Membership Type** of a new member.
#
# ---
#
# # 3️⃣ Mobile Phone Analysis
#
# Build a machine learning solution for **Mobile Phone Analysis**.
#
# Features:
#
# - RAM
# - Storage
#
# Tasks:
#
# 1. Group mobile phones into clusters based on their specifications.
# 2. Predict the **Brand Category** of a phone.
#
# ---
#
# # 4️⃣ Vehicle Analysis
#
# Build a machine learning solution for **Vehicle Analysis**.
#
# Features:
#
# - Speed
# - Mileage
#
# Tasks:
#
# 1. Create clusters of vehicles based on their characteristics.
# 2. Predict the **Vehicle Type**.
#
# ---
#
# # 5️⃣ University Admission Analysis
#
# Build a machine learning solution for **University Admission Analysis**.
#
# Features:
#
# - CGPA
# - Entrance Score
#
# Tasks:
#
# 1. Group students into clusters based on their academic performance.
# 2. Predict the **Admission Status** of a student.
#
# ---
