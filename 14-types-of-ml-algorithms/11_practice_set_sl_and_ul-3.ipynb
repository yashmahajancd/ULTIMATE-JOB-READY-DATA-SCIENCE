# %% [markdown]
# # 🧠 Questions - Combination of Supervised + Unsupervised Learning
#
# ---
#
# # 1️⃣ Customer Segmentation and Churn Prediction
#
# A telecom company wants to:
#
# 1. Segment customers into **3 clusters** based on:
#    - Monthly Charges
#    - Tenure
# 2. Predict whether a customer will **Churn** or **Stay**.
#
# ### Dataset
#
# ```python
# import pandas as pd
#
# data = pd.DataFrame({
#     "MonthlyCharges": [30, 35, 40, 70, 75, 80],
#     "Tenure": [2, 3, 5, 20, 25, 30],
#     "Churn": [1, 1, 1, 0, 0, 0]
# })
# ```
#
# Predict the outcome for:
#
# ```python
# MonthlyCharges = 65
# Tenure = 18
# ```
#
# ---
#
# # 2️⃣ Employee Performance Analysis
#
# A company wants to:
#
# 1. Cluster employees into **performance groups**.
# 2. Predict whether an employee deserves a **Promotion**.
#
# Features:
#
# - Experience
# - Performance Score
#
# Target:
#
# - Yes
# - No
#
# ---
#
# # 3️⃣ Credit Card Fraud Risk Analysis
#
# A bank wants to:
#
# 1. Cluster transactions into **Low**, **Medium**, and **High Risk** groups.
# 2. Predict whether a transaction is **Fraud**.
#
# Features:
#
# - Transaction Amount
# - Transaction Frequency
#
# ---
#
# # 4️⃣ Online Shopping Recommendation System
#
# An e-commerce company wants to:
#
# 1. Segment users based on:
#
#    - Time Spent
#    - Purchase Amount
#
# 2. Predict whether the customer will **Buy Again**.
#
# ---
#
# # 5️⃣ Hospital Patient Risk Analysis
#
# A hospital wants to:
#
# 1. Group patients into **risk categories**.
# 2. Predict whether a patient should be **Admitted**.
#
# Features:
#
# - Age
# - Blood Pressure
#
# ---
